# %%
import pandas as pd
import numpy as np
import os

# %%
PATH_MOVIELENS = os.path.join('..','dataset','MovieLens')

# %%
movies = pd.read_csv(os.path.join(PATH_MOVIELENS,'movies.csv'))
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings = pd.read_csv(os.path.join(PATH_MOVIELENS,'ratings.csv'))
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
ratings.shape
# Out:
# (25000095, 4)

# %%
genometags = pd.read_csv(os.path.join(PATH_MOVIELENS,'genome-tags.csv'))
genometags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
genometags.shape
# Out:
# (1128, 2)

# %%
tags = pd.read_csv(os.path.join(PATH_MOVIELENS,'tags.csv'))
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
tags.shape
# Out:
# (1093360, 4)

# %%
genome_scores = pd.read_csv(os.path.join(PATH_MOVIELENS,'genome-scores.csv'))
genome_scores.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02875
# 1        1      2    0.02375
# 2        1      3    0.06250
# 3        1      4    0.07575
# 4        1      5    0.14075

# %%
genome_scores.shape
# Out:
# (15584448, 3)

# %%
movies.shape[0]* genometags.shape[0]
# Out:
# 70413144

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
links = pd.read_csv(os.path.join(PATH_MOVIELENS,'links.csv'))
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movies[movies['title'].str.contains('Avatar')]
# Out:
#        movieId                                         title  \
# 14102    72998                                 Avatar (2009)
# 19997   103676   My Avatar and Me (Min Avatar og mig) (2010)
# 46636   172851  Avatar: Creating the World of Pandora (2010)
#
#                              genres
# 14102  Action|Adventure|Sci-Fi|IMAX
# 19997                   Documentary
# 46636                   Documentary
